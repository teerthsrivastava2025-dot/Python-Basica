# %%
l1 = [3,2,4,'five', ['etc','etc'],{'key1','value1'}]
print(l1)
# Out:
# [3, 2, 4, 'five', ['etc', 'etc'], {'key1', 'value1'}]

# %%
l1=[1,5,5,6]
print(l1)
print(l1[3])
l1[3]=58
print(l1)
# Out:
# [1, 5, 5, 6]
# 6
# [1, 5, 5, 58]

# %%
#DICTIONARY
stu={'Name':'Teerth',
     'Age':19}
print(stu)
print(type(stu))
stu['Age']
# Out:
# {'Name': 'Teerth', 'Age': 19}
# <class 'dict'>
# 19

# %%
stu['Age']=18
print(stu)
# Out:
# {'Name': 'Teerth', 'Age': 18}

# %%
calendar=(1,2,3,4,5,6)
print(calendar)
print(type(calendar))
calendar[2]
# Out:
# (1, 2, 3, 4, 5, 6)
# <class 'tuple'>
# 3

# %%
#MOVIE_CINEMA
print('Welcome to SSE Productions')
print('*'*45)
#SHOPKEEPER
movies=['Inception','Interstellar','Avengers:Endgame']
print('Available shows')
print(movies)
# Out:
# Welcome to SSE Productions
# *********************************************
# Available shows
# ['Inception', 'Interstellar', 'Avengers:Endgame']

# %%
new_movie = 'Avatar: Fire and Ash'
movies.append(new_movie)
print(movies)
# Out:
# ['Inception', 'Interstellar', 'Avengers:Endgame', 'Avatar: Fire and Ash']

# %%
seats=('A1','A2','A3','A4')
print('Available seats',seats)
# Out:
# Available seats ('A1', 'A2', 'A3', 'A4')

# %%
movie_to_watch=input('Which Movie do You want to See:')
seat=input('Seat No.')
booking_key=(movie_to_watch+'-'+seat)
print(booking_key)
# Out:
# Which Movie do You want to See: Avengers:Endgame
# Seat No. A4
# Avengers:Endgame-A4

# %%
bookings = {}

# %%
bookings[booking_key] = 'Booked'
print('Booking successful')
print(bookings)
# Out:
# Booking successful
# {'Inception-A2': 'Booked', 'Interstellar-A3': 'Booked', 'Avengers:Endgame-A4': 'Booked'}
