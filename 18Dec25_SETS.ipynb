# %%
names=['yash','kirti','kunal','yash','yash']
print(names)
# Out:
# ['yash', 'kirti', 'kunal', 'yash', 'yash']

# %%
roll_numbers={101,102,105,110,100}
print(roll_numbers)
print(type(roll_numbers))
#SET OF CITIES-
cities={'Pune','Kerala','Bangalore'}
print(cities)
print(type(cities))
cities.remove('Pune')
print(cities)
cities.add('Mumbai')
print(cities)
# Out:
# {100, 101, 102, 105, 110}
# <class 'set'>
# {'Pune', 'Bangalore', 'Kerala'}
# <class 'set'>
# {'Bangalore', 'Kerala'}
# {'Bangalore', 'Mumbai', 'Kerala'}

# %%
#MUSIC GENRE ANALYSER
friend1={'EDM','Bollytech','House'}
friend2={'HipHop','Bollytech','Country'}
print(friend1)
print(friend2)
# Out:
# {'House', 'EDM', 'Bollytech'}
# {'Country', 'HipHop', 'Bollytech'}

# %%
friend1 = { "edm" , "bollytech" , "house" }
friend2 = { "hiphop" , "bollytech" , "country" }

print(friend1)
print(friend2)

print( friend1 | friend2 )
print( friend1 & friend2 )
# Out:
# {'edm', 'bollytech', 'house'}
# {'country', 'hiphop', 'bollytech'}
# {'edm', 'hiphop', 'house', 'country', 'bollytech'}
# {'bollytech'}
