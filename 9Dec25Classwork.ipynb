# %%
print('check')
print('9/12/2025 Classwork')
# Out:
# check
# 9/12/2025 Classwork

# %%
num1 = 10
num2 = 30.5
text='This is a sample text'
print(num1)
print(num2)
print(text)
print(type(num1))
print(type(num2))
print(type(text))
# Out:
# 10
# 30.5
# This is a sample text
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
n1 =250
n2 =35
#logic to add, subtarct, multiply, divide
add = n1+n2
print('The sum is :',add)
subtract = n1 -n2
print('The difference is :',subtract)
multiply = n1*n2
print('The product is :',multiply)
divide= n1/n2
print('The quotient is :',divide)
# Out:
# The sum is : 285
# The difference is : 215
# The product is : 8750
# The quotient is : 7.142857142857143

# %%
n1 = int(input('Enter the 1st Number:'))
n2 = int(input('Enter the 2nd Number:'))
#logic to add, subtarct, multiply, divide
add = n1+n2
print('The sum is :',add)
subtract = n1 -n2
print('The difference is :',subtract)
multiply = n1*n2
print('The product is :',multiply)
divide= n1/n2
print('The quotient is :',divide)
# Out:
# Enter the 1st Number: 23
# Enter the 2nd Number: 45
# The sum is : 68
# The difference is : -22
# The product is : 1035
# The quotient is : 0.5111111111111111

# %% [raw]
# Password Achieving
# With the help of string

# %%
Division='Div C'
Lecturer='Divesh Jadhwani'
Subject='Python'
Password_by_teacher = 12345
Password_by_student = 12345

print('Attendance Slot created for:')
print('The Division is', Division)
print('The Lecturer is', Lecturer)
print('The Subject is', Subject)

#== is used as exactly equal to
if Password_by_teacher == Password_by_student:
    print('Attendance given')
else:
    print('Attendance not given')
# Out:
# Attendance Slot created for:
# The Division is Div C
# The Lecturer is Divesh Jadhwani
# The Subject is Python
# Attendance given

# %%
Division=input('Division:')
Lecturer=input('Lecturer:')
Subject=input('Subject:')
Password_by_teacher = 12345
Password_by_student = int(input('Password by student:'))

print('Attendance Slot created for:')
print('The Division is', Division)
print('The Lecturer is', Lecturer)
print('The Subject is', Subject)

#== is used as exactly equal to
if Password_by_teacher == Password_by_student:
    print('Attendance given')
else:
    print('Attendance not given')
# Out:
# Division: C
# Lecturer: Divesh Jadhwani
# Subject: Python
# Password by student: 12345
# Attendance Slot created for:
# The Division is C
# The Lecturer is Divesh Jadhwani
# The Subject is Python
# Attendance given
